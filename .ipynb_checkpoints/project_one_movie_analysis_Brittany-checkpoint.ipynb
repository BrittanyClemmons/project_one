# %%
#Import dependencies
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Import data
csv_data = pd.read_csv("Resources/movie_metadata.csv", encoding="utf-8")
df = pd.DataFrame(csv_data)

# %%
df_count = df.count()

# %%
df_clean = df.dropna()

# %%
df_clean_count = df_clean.count()

# %%
df = df_clean
df.reset_index(drop=True)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 3751  Color    Olivier Assayas                    81.0     110.0
# 3752  Color       Jafar Panahi                    64.0      90.0
# 3753  Color      Shane Carruth                   143.0      77.0
# 3754  Color   Robert Rodriguez                    56.0      81.0
# 3755  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
df.head(10)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 5   Color     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
#
#     director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                       0.0                   855.0   Joel David Moore
# 1                     563.0                  1000.0      Orlando Bloom
# ...

# %%
df.imdb_score.min(),df.imdb_score.max()
# Out:
# (1.6, 9.3)

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## Analysis of Directors and their IMDB Scores

# %% [markdown]
# This analysis

# %%
df.imdb_score.describe()
# Out:
# count    3756.000000
# mean        6.465282
# std         1.056247
# min         1.600000
# 25%         5.900000
# 50%         6.600000
# 75%         7.200000
# max         9.300000
# Name: imdb_score, dtype: float64

# %%
#Create a dataframe of directors and imdb score for each movie
directors_and_imdb = pd.DataFrame(df[['director_name', 'imdb_score']])
directors_and_imdb
# Out:
#           director_name  imdb_score
# 0         James Cameron         7.9
# 1        Gore Verbinski         7.1
# 2            Sam Mendes         6.8
# 3     Christopher Nolan         8.5
# 5        Andrew Stanton         6.6
# ...                 ...         ...
# 5026    Olivier Assayas         6.9
# 5027       Jafar Panahi         7.5
# 5033      Shane Carruth         7.0
# 5035   Robert Rodriguez         6.9
# 5042           Jon Gunn         6.6
#
# [3756 rows x 2 columns]

# %%
#Create a DataFrame of directors and IMDB Scores in which the score is above the average

directors_and_imdb_above_avg = directors_and_imdb[directors_and_imdb['imdb_score'] > 6.5]
directors_and_imdb_above_avg.reset_index(drop=True)
# Out:
#           director_name  imdb_score
# 0         James Cameron         7.9
# 1        Gore Verbinski         7.1
# 2            Sam Mendes         6.8
# 3     Christopher Nolan         8.5
# 4        Andrew Stanton         6.6
# ...                 ...         ...
# 1897    Olivier Assayas         6.9
# 1898       Jafar Panahi         7.5
# 1899      Shane Carruth         7.0
# 1900   Robert Rodriguez         6.9
# 1901           Jon Gunn         6.6
#
# [1902 rows x 2 columns]

# %%
directors_and_imdb_above_avg_group = directors_and_imdb_above_avg.groupby('director_name').count()
directors_and_imdb_above_avg_group= directors_and_imdb_above_avg_group['imdb_score'].nlargest(30)
directors_and_imdb_above_avg_group
# Out:
# director_name
# Steven Spielberg        22
# Martin Scorsese         16
# Clint Eastwood          15
# Woody Allen             14
# Ridley Scott            13
# Peter Jackson           11
# Robert Zemeckis         11
# Richard Linklater       10
# Steven Soderbergh       10
# Tim Burton              10
# Danny Boyle              9
# David Fincher            9
# John Carpenter           9
# Ron Howard               9
# Spike Lee                9
# Chris Columbus           8
# Christopher Nolan        8
# Michael Bay              8
# Oliver Stone             8
# Quentin Tarantino        8
# Rob Reiner               8
# Sam Mendes               8
# Ang Lee                  7
# Barry Levinson           7
# David O. Russell         7
# Edward Zwick             7
# Francis Ford Coppola     7
# Guy Ritchie              7
# James Cameron            7
# James Wan                7
# Name: imdb_score, dtype: int64

# %%
directors_and_imdb_above_avg_group = directors_and_imdb_above_avg.groupby('director_name').mean()
directors_above_avg_count = directors_and_imdb_above_avg_group['imdb_score'].nlargest(30)
directors_count = pd.DataFrame(directors_above_avg_count)
directors_count
# Out:
#                                   imdb_score
# director_name
# Irvin Kershner                      8.800000
# Akira Kurosawa                      8.700000
# Charles Chaplin                     8.600000
# Tony Kaye                           8.600000
# Alfred Hitchcock                    8.500000
# Damien Chazelle                     8.500000
# Florian Henckel von Donnersmarck    8.500000
# Majid Majidi                        8.500000
# Roger Allers                        8.500000
# Ron Fricke                          8.500000
# Sergio Leone                        8.433333
# Christopher Nolan                   8.425000
# Asghar Farhadi                      8.400000
# Richard Marquand                    8.400000
# Billy Wilder                        8.300000
# Fritz Lang                          8.300000
# Lee Unkrich                         8.300000
# Lenny Abrahamson                    8.300000
# Oliver Hirschbiegel                 8.300000
# ...

# %%
directors_and_imdb_above_avg_group = directors_and_imdb_above_avg.groupby('director_name').mean()
directors_above_avg_mean = directors_and_imdb_above_avg_group['imdb_score'].nlargest(30)
directors_score = pd.DataFrame(directors_above_avg_mean)

# %%
df_merge_director_imdb = pd.concat([directors_count, directors_score, on='director_name'])
df_merge_director_imdb
# Out:
#   File "<ipython-input-168-525397bbb511>", line 1
#     df_merge_director_imdb = pd.concat([directors_count, directors_score, on='director_name'])
#                                                                             ^
# SyntaxError: invalid syntax

# %%
#Create a group based on directors
directors_imdb_group = directors_and_imdb.groupby('director_name')

#Average imdb score per director
directors_avg_imdb = directors_imdb_group['imdb_score'].mean().nlargest(10)
directors_avg_imdb

# %%
directors_and_imdb[directors_and_imdb['director_name']=='Akira Kurosawa']

# %%
directors_and_imdb[directors_and_imdb['director_name']=='Charles Chaplin']

# %%
#Create a group based on directors
directors_imdb_group = directors_and_imdb.groupby('director_name')

# %%
#Average imdb score per director
directors_avg_imdb = directors_imdb_group['imdb_score'].mean().nlargest(10)
directors_avg_imdb

# %%
directors_avg_imdb_chart = directors_avg_imdb.plot(kind='bar',figsize=(10,5))
directors_avg_imdb_chart
