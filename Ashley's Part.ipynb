# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


#Import data
csv_data = pd.read_csv("Resources/movie_metadata.csv", encoding="utf-8")
df = pd.DataFrame(csv_data)
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.count()
# Out:
# color                        5024
# director_name                4939
# num_critic_for_reviews       4993
# duration                     5028
# director_facebook_likes      4939
# actor_3_facebook_likes       5020
# actor_2_name                 5030
# actor_1_facebook_likes       5036
# gross                        4159
# genres                       5043
# actor_1_name                 5036
# movie_title                  5043
# num_voted_users              5043
# cast_total_facebook_likes    5043
# actor_3_name                 5020
# facenumber_in_poster         5030
# plot_keywords                4890
# movie_imdb_link              5043
# num_user_for_reviews         5022
# language                     5031
# country                      5038
# content_rating               4740
# budget                       4551
# title_year                   4935
# actor_2_facebook_likes       5030
# imdb_score                   5043
# aspect_ratio                 4714
# ...

# %%
df_clean=df.dropna()

# %%
df_clean
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
df_clean.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
grouped_df = df_clean.groupby(['director_name', 'movie_title'])
#popularity_df = pd.DataFrame(grouped_df["num_critic_for_reviews"])
#popularity_df

# %%
x = df_clean[["director_name", "movie_title", "gross", "num_critic_for_reviews",
                            "num_user_for_reviews"]]
x
# Out:
#           director_name                                movie_title  \
# 0         James Cameron                                    Avatar
# 1        Gore Verbinski  Pirates of the Caribbean: At World's End
# 2            Sam Mendes                                   Spectre
# 3     Christopher Nolan                     The Dark Knight Rises
# 5        Andrew Stanton                               John Carter
# ...                 ...                                        ...
# 5026    Olivier Assayas                                     Clean
# 5027       Jafar Panahi                                The Circle
# 5033      Shane Carruth                                    Primer
# 5035   Robert Rodriguez                               El Mariachi
# 5042           Jon Gunn                         My Date with Drew
#
#             gross  num_critic_for_reviews  num_user_for_reviews
# 0     760505847.0                   723.0                3054.0
# ...

# %%
y = df_clean[["director_name", "movie_title", "gross", "budget", "imdb_score"]]
y
# Out:
#           director_name                                movie_title  \
# 0         James Cameron                                    Avatar
# 1        Gore Verbinski  Pirates of the Caribbean: At World's End
# 2            Sam Mendes                                   Spectre
# 3     Christopher Nolan                     The Dark Knight Rises
# 5        Andrew Stanton                               John Carter
# ...                 ...                                        ...
# 5026    Olivier Assayas                                     Clean
# 5027       Jafar Panahi                                The Circle
# 5033      Shane Carruth                                    Primer
# 5035   Robert Rodriguez                               El Mariachi
# 5042           Jon Gunn                         My Date with Drew
#
#             gross       budget  imdb_score
# 0     760505847.0  237000000.0         7.9
# 1     309404152.0  300000000.0         7.1
# ...

# %%
good_movies = y.loc[df_clean["imdb_score"] > 7]
good_movies
# Out:
#           director_name                                movie_title  \
# 0         James Cameron                                    Avatar
# 1        Gore Verbinski  Pirates of the Caribbean: At World's End
# 3     Christopher Nolan                     The Dark Knight Rises
# 7          Nathan Greno                                   Tangled
# 8           Joss Whedon                   Avengers: Age of Ultron
# ...                 ...                                        ...
# 4998       Kevin Jordan               Smiling Fish & Goat on Fire
# 5008        Kevin Smith                                    Clerks
# 5011        Neil LaBute                     In the Company of Men
# 5015  Richard Linklater                                   Slacker
# 5027       Jafar Panahi                                The Circle
#
#             gross       budget  imdb_score
# 0     760505847.0  237000000.0         7.9
# 1     309404152.0  300000000.0         7.1
# ...

# %%
z = y.sort_values("imdb_score", ascending=False)
z.head(10)
# Out:
#              director_name                                        movie_title  \
# 1937        Frank Darabont                          The Shawshank Redemption
# 3466  Francis Ford Coppola                                     The Godfather
# 66       Christopher Nolan                                   The Dark Knight
# 2837  Francis Ford Coppola                            The Godfather: Part II
# 339          Peter Jackson     The Lord of the Rings: The Return of the King
# 4498          Sergio Leone                    The Good, the Bad and the Ugly
# 1874      Steven Spielberg                                  Schindler's List
# 3355     Quentin Tarantino                                      Pulp Fiction
# 836        Robert Zemeckis                                      Forrest Gump
# 270          Peter Jackson  The Lord of the Rings: The Fellowship of the R...
#
#             gross       budget  imdb_score
# 1937   28341469.0   25000000.0         9.3
# ...

# %%
z = y.sort_values("gross", ascending=False)
z.head(20)
# Out:
#           director_name                                  movie_title  \
# 0         James Cameron                                      Avatar
# 26        James Cameron                                     Titanic
# 29      Colin Trevorrow                              Jurassic World
# 794         Joss Whedon                                The Avengers
# 17          Joss Whedon                                The Avengers
# 66    Christopher Nolan                             The Dark Knight
# 240        George Lucas   Star Wars: Episode I - The Phantom Menace
# 3024       George Lucas          Star Wars: Episode IV - A New Hope
# 8           Joss Whedon                     Avengers: Age of Ultron
# 3     Christopher Nolan                       The Dark Knight Rises
# 582      Andrew Adamson                                     Shrek 2
# 3080   Steven Spielberg                  E.T. the Extra-Terrestrial
# 186    Francis Lawrence             The Hunger Games: Catching Fire
# ...

# %%
a = df_clean[["movie_title", "actor_1_name", "actor_1_facebook_likes"]]
b = a.sort_values("actor_1_facebook_likes", ascending=False)
b.head(10)
# Out:
#                                  movie_title     actor_1_name  \
# 1902  Anchorman: The Legend of Ron Burgundy     Darcy Donavan
# 4592                               Hardflip      Matthew Ziff
# 1223                  The Final Destination      Krista Allen
# 2939                             Quarantine   Andrew Fiscella
# 2269                                Armored   Andrew Fiscella
# 972                                Firewall     Jimmy Bennett
# 105                                Poseidon     Jimmy Bennett
# 74                            Evan Almighty     Jimmy Bennett
# 2385                  The Amityville Horror     Jimmy Bennett
# 555                                 Hostage     Jimmy Bennett
#
#       actor_1_facebook_likes
# 1902                640000.0
# 4592                260000.0
# 1223                164000.0
# 2939                137000.0
# 2269                137000.0
# 972                  87000.0
# 105                  87000.0
# 74                   87000.0
# ...

# %%
Popularity = df_clean.groupby(['actor_1_name']).count()
print(Popularity)
# Out:
#                  color  director_name  num_critic_for_reviews  duration  \
# actor_1_name
# 50 Cent              1              1                       1         1
# Aaliyah              1              1                       1         1
# Aasif Mandvi         1              1                       1         1
# Abbie Cornish        3              3                       3         3
# Adam Arkin           1              1                       1         1
# ...                ...            ...                     ...       ...
# Zak Penn             1              1                       1         1
# Zoe Kazan            1              1                       1         1
# Zooey Deschanel      9              9                       9         9
# Zoë Kravitz          2              2                       2         2
# Óscar Jaenada        1              1                       1         1
#
#                  director_facebook_likes  actor_3_facebook_likes  \
# actor_1_name
# ...

# %%
#Calculate profit and add column to existing data frame
df_clean['profit'] = df_clean["gross"] - df_clean["budget"]
profit_df = df_clean
a = profit_df[["movie_title", "movie_facebook_likes", "profit"]]
b = a.sort_values("profit", ascending=False)
c = b.nlargest(50, "profit")
c
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                             movie_title  movie_facebook_likes  \
# 0                                               Avatar                  33000
# 29                                      Jurassic World                 150000
# 26                                             Titanic                  26000
# 3024                Star Wars: Episode IV - A New Hope                  33000
# 3080                        E.T. the Extra-Terrestrial                  34000
# 17                                        The Avengers                 123000
# ...

# %%
plt.scatter(x=c['movie_facebook_likes'], y=c['profit'])
plt.title("Movie Popularity vs Profit")
plt.xlabel("Facebook Likes")
plt.ylabel("Profit (in hundreds of millions)")
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\admin\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#Duration vs IMBD Scores

e = df_clean[["movie_title", "duration", "imdb_score"]]
e
# Out:
#                                     movie_title  duration  imdb_score
# 0                                       Avatar      178.0         7.9
# 1     Pirates of the Caribbean: At World's End      169.0         7.1
# 2                                      Spectre      148.0         6.8
# 3                        The Dark Knight Rises      164.0         8.5
# 5                                  John Carter      132.0         6.6
# ...                                         ...       ...         ...
# 5026                                     Clean      110.0         6.9
# 5027                                The Circle       90.0         7.5
# 5033                                    Primer       77.0         7.0
# 5035                               El Mariachi       81.0         6.9
# 5042                         My Date with Drew       90.0         6.6
#
# [3756 rows x 3 columns]

# %%
plt.scatter(x=e['duration'], y=e['imdb_score'])
plt.title("Duration impact on IMDB Score")
plt.xlabel("duration")
plt.ylabel("imdb_score")
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-2b19a714f40d> in <module>
#       3 plt.xlabel("duration")
#       4 plt.ylabel("imdb_score")
# ----> 5 z = np.polyfit(x, y, 1)
#       6 p = np.poly1d(z)
#       7 plt.plot(x,p(x),"r--")
#
# ~\Anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     587     """
#     588     order = int(deg) + 1
# --> 589     x = NX.asarray(x) + 0.0
#     590     y = NX.asarray(y) + 0.0
#     591
#
# TypeError: can only concatenate str (not "float") to str
